# %%
# %matplotlib
import time
import tweepy
from textblob import TextBlob
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: Qt5Agg

# %%
consumer_key= '7cjrKiWroBPNm8Gh6Trv539GE'
consumer_secret= '7tzoBxbXYYkb2P3zYtFClWY7XEQPSro5uxyJVMIzRKnW74FlPL'

access_token='3236227405-b2yvc5NlddUwdMm6UFsKHBETQytiTj9zp59Bx7Y'
access_token_secret='k0XZgTp9tgYb8kQjRwldNSmWLS5JS7p3IPnd7MLxxaD6n'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#Step 3 - Retrieve Tweets

places = api.geo_search(query="USA", granularity="country")
place_id = places[0].id
print(place_id)
#tweets = api.search(q="place:%s" %(place_id))

positive = 0
negative = 0
compound = 0
count = 0

intime = time.time()
plt.ion()
# Out:
# 96683cc9126741d1

# %%
def on_data():
    global positive 
    global negative
    global compound
    global count
    global intime
    count = count + 1
    senti = 0
    print (intime)
    #initime = time.time()
    for tweet in public_tweets:
        print(tweet.text)
        print (intime)
        t = int(time.time()-intime)
        #Step 4 Perform Sentiment Analysis on Tweets
        analysis = TextBlob(tweet.text)
        print(analysis.sentiment)
        print("")
        senti = senti + analysis.sentiment.polarity
        if analysis.sentiment.polarity >= 0:
            positive = positive + analysis.sentiment.polarity
        else:
            negative = negative + analysis.sentiment.polarity
    compound = compound + senti
    print(count)
    print(senti)
    print(t)
    print(str(positive) + ' ' + str(negative) + ' ' + str(compound))   

    plt.axis([0, 100, -50, 50])
    plt.xlabel('Time')
    plt.ylabel('Sentiment')
    plt.plot([t],[positive],'go',[t],[negative],'ro',[t],[compound],'bo')
    plt.show()
    plt.pause(0.0001)
    return True
    
for _ in range(50):
    #public_tweets = api.search('Donald Trump')
    #places = api.geo_search(query="India", granularity="country")
    #place_id = places[0].id
    #print(place_id)
    public_tweets = api.search(q="place:%s" %(place_id))
    plt.ion()
    on_data()
# Out:
# 1509264938.2285674
# Looking like a damn horse 😂 https://t.co/3N0a2iGowR
# 1509264938.2285674
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# The traffic never stops 😪 why are we not moving and it's 4 AM. I just wanna get to the bed. FAST!
# 1509264938.2285674
# Sentiment(polarity=0.25, subjectivity=0.6)
#
# I've felt guilty about getting stuff for myself lately. But it had to be done 🙋🏿‍♀️
# 1509264938.2285674
# Sentiment(polarity=-0.4, subjectivity=0.8)
#
# #SouthCarolina #fisting latex #discreet #sloppy kink #directchat #liveonchaturbate cumtribute #whatsapp #hottie https://t.co/Ajs0mFvBzB
# 1509264938.2285674
# Sentiment(polarity=-0.4166666666666667, subjectivity=0.75)
#
# Spent my night at the hospital, fucking lit 😒
# 1509264938.2285674
# Sentiment(polarity=-0.35, subjectivity=0.45)
#
# @Questionizer500 @WSJ The 80's was the best thing that happened to music be it the pop or the hard rock and metal,… https://t.co/4KCMPUwExa
# 1509264938.2285674
# ...
